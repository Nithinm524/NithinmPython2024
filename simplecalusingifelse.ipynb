# %% [markdown]
# simple calculation using if else

# %%
num1=float(input("enter first number"))
num2=float(input("enter second numbers"))
operation=input("enter operation(+,-,*,/)")
if operation=="+":
    print("result",num1+num2)
elif operation=="-":
    print("result",num1-num2)
else operation=="*":
