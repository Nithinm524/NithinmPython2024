# %% [markdown]
# forloop

# %%
for i in range(5):
   print("iteration:",i)
# Out:
# iteration: 0
# iteration: 1
# iteration: 2
# iteration: 3
# iteration: 4

# %%
for i in range(5):
   print("iteration:",i)
# Out:
# iteration: 0
# iteration: 1
# iteration: 2
# iteration: 3
# iteration: 4

# %%
for i in range(5,20,10):
    print("iteration:",i)
# Out:
# iteration: 5
# iteration: 15
