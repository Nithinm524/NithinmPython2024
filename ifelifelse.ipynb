# %% [markdown]
# if elif else

# %%
marks=int(input("enter your marks:"))
if marks>=90:
    print("grade: A")
elif marks>=75:
    print("grade: B")
else:
    print("grade: F")
# Out:
# enter your marks:89
# grade: B
