# %% [markdown]
# control flow loops

# %% [markdown]
# break

# %%
for i in range(10):
    if i==5:
       break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# continue

# %%
for i in range(10):
  if i==5:
      break
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# pass

# %%
for i in range(3):
   if i==5:
      pass
   print(i)
# Out:
# 0
# 1
# 2
