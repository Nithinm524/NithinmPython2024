# %% [markdown]
# positive or negative numbers

# %%
a=int(input("enter a number:"))
if a>0:
   print("positive number")
elif a<0:
   print("negative number")
else:
   print("zero")
# Out:
# enter a number:6
# positive number
